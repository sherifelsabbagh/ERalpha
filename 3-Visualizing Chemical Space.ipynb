# %%
import pandas as pd 
import chemplot
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset_standard.csv",sep="\t")

# %%
df.head()
# Out:
#   Molecule ChEMBL ID                                             smiles  \
# 0       CHEMBL370039                    O=C(Cc1cc2ccccc2o1)c1ccc(O)cc1O
# 1      CHEMBL3774737  COC[C@H](C)CN1[C@H](c2c(F)cc(/C=C/C(=O)O)cc2F)...
# 2      CHEMBL3775116  CC(C)CN1[C@@H](c2ccc(/C=C/C(=O)O)cc2)c2ccc(O)c...
# 3      CHEMBL1597831  O=C(CCCCCn1c(=S)[nH]c2ccccc2c1=O)N1CCC(N(Cc2cc...
# 4      CHEMBL1455849  O=C(CCCCCn1c(=S)[nH]c2ccccc2c1=O)N1CCN(c2cccc(...
#
#   #RO5 Violations  label     pIC50    Molwt     LogP  HBA  HBD
# 0               0      0  4.067019  268.268  3.26940    4    2
# 1               0      1  8.920819  431.479  4.38670    4    2
# 2               0      1  6.017729  379.500  4.87210    3    2
# 3               2      1  6.920819  540.733  6.31729    5    1
# 4               0      1  6.075721  481.578  3.87649    7    1

# %%
df.shape
# Out:
# (1559, 9)

# %%
from chemplot import Plotter

# %%
cp = Plotter.from_smiles(df["smiles"],target=df["label"],target_type="C",sim_type="structural")

# %%
cp.pca()
# Out:
#       PC-1 (9%)  PC-2 (5%)  target
# 0     -1.554018  -1.025355       0
# 1      0.144500   1.188542       1
# 2     -0.127133   0.606510       1
# 3     -1.422459   2.822442       1
# 4     -1.595092   2.903465       1
# ...         ...        ...     ...
# 1554  -0.124632   4.470891       1
# 1555  -0.805025  -1.531390       1
# 1556  -1.153897  -1.254915       1
# 1557  -0.712951  -0.189934       1
# 1558   3.598637  -0.311085       1
#
# [1559 rows x 3 columns]

# %%
cp.visualize_plot()
# Out:
# <AxesSubplot:label='scatter', title={'center':'PCA plot'}, xlabel='PC-1 (9%)', ylabel='PC-2 (5%)'>

# %%
cp = Plotter.from_smiles(df["smiles"],target=df["label"],target_type="C",sim_type="structural")
cp.pca()
cp.interactive_plot(show_plot=True)
# Out:
# Figure(id='1002', ...)

# %%
cp.cluster()
# Out:
#       PC-1 (9%)  PC-2 (5%)  target  clusters
# 0     -1.554018  -1.025375       0         0
# 1      0.144498   1.188557       1         3
# 2     -0.127134   0.606534       1         3
# 3     -1.422458   2.822317       1         2
# 4     -1.595091   2.903279       1         2
# ...         ...        ...     ...       ...
# 1554  -0.124628   4.470787       1         4
# 1555  -0.805026  -1.531346       1         0
# 1556  -1.153896  -1.254958       1         0
# 1557  -0.712953  -0.189932       1         3
# 1558   3.598639  -0.311087       1         1
#
# [1559 rows x 4 columns]

# %%
cp.interactive_plot(clusters=True,show_plot=True)
# Out:
# Tabs(id='1390', ...)
